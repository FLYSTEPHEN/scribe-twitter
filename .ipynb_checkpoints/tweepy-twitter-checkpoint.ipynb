# %%
import tweepy
consumer_key = 'ih3a9W70Ads4yQdMCuLciml8H'
consumer_secret = 'hY0lPD9o9S9YEKTHhSBOkVKIaAHOHJmhdC23VCRVsAWr4GftSF'
access_token = '1033231870190739456-4KnnjUEIoeiiRLNnS8Yyp1WKGjKG7Z'
access_token_secret = 'QBHOE74iloC0cJID36RhaFi0dMJUklRR0qz9dUruZDKq4'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()
# for tweet in public_tweets:
#     print(tweet.text)
ac = api.followers('@PDChina')
ac
# Out:
# [User(_api=<tweepy.api.API object at 0x103dca7f0>, _json={'id': 2722924144, 'id_str': '2722924144', 'name': 'Atiku Luke', 'screen_name': 'atiku_luke', 'location': 'Uganda', 'description': 'Call me tiger', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 1, 'friends_count': 75, 'listed_count': 0, 'created_at': 'Thu Jul 24 12:04:16 +0000 2014', 'favourites_count': 10, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1088491746005274627/_T3msDKx_normal.jpg', 'profile_image_url_https': 'https:/
# ...

# %%
import requests
requests.get('https://api.twitter.com/1.1/lists/subscriptions.json?cursor=-1&screen_name=episod&count=5')
# Out:
# <Response [400]>

# %%
class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)

myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
myStream.filter(track=['python'])
myStream.filter(follow=["2211149702"])
myStream.filter(track=['python'], async=True)
# Out:
#   File "<ipython-input-6-6456917fe6d9>", line 10
#     myStream.filter(track=['python'], async=True)
#                                           ^
# SyntaxError: invalid syntax
